# %%
import os
from os.path import join, dirname, abspath
import pandas as pd
import re
import requests
import fitz
import time
from typing import List
from bs4 import BeautifulSoup
from openai import AzureOpenAI
from markdownify import markdownify as md
from langchain.docstore.document import Document
from langchain.text_splitter import TokenTextSplitter
from langchain_openai import AzureOpenAIEmbeddings

from langchain_community.vectorstores.azuresearch import (
    AzureSearch,
    FIELDS_ID,
    FIELDS_CONTENT,
    FIELDS_CONTENT_VECTOR,
    FIELDS_METADATA,
)
from azure.search.documents.indexes.models import (
    SimpleField,
    SearchableField,
    SearchField,
    SearchFieldDataType,
)
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
embeddings = AzureOpenAIEmbeddings(
    azure_endpoint=os.getenv("OPENAI_ENDPOINT"),
    azure_deployment=os.getenv("EMBEDDING_NAME"),
    chunk_size=20480,
    openai_api_key=os.getenv("OPENAI_KEY"),
    openai_api_version=os.getenv("OPENAI_API_VERSION"),
    openai_api_type="azure",
)

# %%
def extract_paragraphs(page: fitz.Page, tables: List[fitz.Rect]):
    page_words = page.get_text("words")
    paragraph_words = [
        w
        for w in page_words
        if not any([fitz.Rect(w[:4]).intersects(r) for r in tables])
    ]

    line_dict = {}
    paragraph_words.sort(key=lambda w: w[0])
    for w in paragraph_words:
        y1 = round(w[3], 1)
        word = w[4]
        line = line_dict.get(y1, [])
        line.append(word)
        line_dict[y1] = line
    lines = [line_dict[y1] for y1 in sorted(line_dict.keys())]
    return "\n".join([" ".join(line) for line in lines])


HTML_CLEANUP_RULES = [
    {
        "target": """Afbeelding met tekst

Automatisch gegenereerde beschrijving""",
        "replacement": "GENERATED_IMAGE_DESCRIPTION",
    },
    {
        "target": """Afbeelding met tabel

Automatisch gegenereerde beschrijving""",
        "replacement": "GENERATED_IMAGE_TABLE_DESCRIPTION",
    },
    {
        "target": """
 |""",
        "replacement": " |",
    },
]

MARKDOWN_CLEANUP_RULES = [
    {
        "target": """
 |""",
        "replacement": " |",
    },
    {
        "target": "\u200b",
        "replacement": "",
    },
    {
        "target": "\xa0",
        "replacement": " ",
    },
]


def pdf_to_html(html_string: str):
    """
    Extracts all paragraphs from a PDF page

    Inputs:
    page    A PyMuPDF page
    tables  A list of the bounding boxes of all tables on the page

    Returns:
    A string with all paragraphs of text on the page, separated by double newlines
    """
    soup = BeautifulSoup(html_string, "html.parser")
    # Filter and format the HTML lines
    filtered_lines = []
    for p_tag in sorted(
        soup.find_all("p"),
        key=lambda x: float(x["style"].split(";")[0].split(":")[1].replace("pt", "")),
    ):
        top_position = float(
            p_tag["style"].split(";")[0].split(":")[1].replace("pt", "")
        )
        left_position = float(
            p_tag["style"].split(";")[1].split(":")[1].replace("pt", "")
        )
        font_size = float(
            p_tag.find("span")["style"].split(";")[1].split(":")[1].replace("pt", "")
        )

        filtered_lines.append(
            {
                "top": top_position,
                "font_size": font_size,
                "content": str(p_tag),
            }
        )

    # format content from HTML as string
    formatted_html = ""
    for _, line in enumerate(filtered_lines):
        formatted_html += line["content"]

    return formatted_html


def sanitize_content(content: str, rules: dict) -> str:
    """
    Replaces content in the `content` string, using the rules specified.

    Inputs:
    content: the text to replace in
    rules: a dictionary of the rules to apply

    Outputs:
    The input string `content`, with all the rules specified in `rules` applied.
    """
    for target, replacement in rules:
        content = content.replace(target, replacement)
    return content


def convert_to_markdown(content: str) -> str:
    """
    Converts a HTML string to equivalent Markdown.

    Inputs:
    content     A text string with HTML

    Returns:
    A string containing the Markdown equivalent of the HTML string.
    """
    markdown = md(
        content,
        newline_style="<br>",
        heading_style="ATX",
        wraps=False,
        wrap_width=1000,
    )
    # Replace instancs of <text> with <<text>>, but not other combinations of angle brackets and/or text
    markdown = re.sub(r"((?<!<)<(?!<)(\w+)(?<!>)>(?!>))", r"\2", markdown)
    return markdown


def clean_markdown(markdown):
    """
    Preprocesses the Markdown text by performing several operations:

    1. Normalize text by lowercasing
    2. Replacing multiple newlines with a single newline character.
    3. Reducing multiple consecutive spaces to a single space.
    4. Replacing long URLs with hashes.
    5. Removing unnecessary symbols from the Markdown text.
    6. Removing stopwords from text.

    Args:
        markdown (str): The input Markdown text to be preprocessed.

    Returns:
        str: The preprocessed Markdown text.
    """
    markdown = markdown.lower()
    markdown = re.sub(r"\n\s*\n", " ", markdown)
    markdown = re.sub(r"[ ]+", " ", markdown)
    markdown = re.sub(r"([^\w\s\[\]\(\$\\.\n\/:#<>{},_\"!@\-*=])\1+", "", markdown)
    return markdown


def pdf_reading(data_folder, file):
    """
    Read in PDF file, convert to markdown via HTML conversion
    """
    pdf_file = fitz.open(f"{data_folder}/{file}")
    markdown_dict = {}
    for idx, page in enumerate(pdf_file):
        # convert pdf text --> html --> markdown to keep formatting
        # use table position to prevent table text to be added in this step
        page_html = pdf_to_html(page.get_text("html"))
        html_sanitized = sanitize_content(page_html, HTML_CLEANUP_RULES)
        markdown = convert_to_markdown(html_sanitized)
        markdown = sanitize_content(markdown, MARKDOWN_CLEANUP_RULES)
        markdown = clean_markdown(markdown)
        if len(markdown) > 10:
            markdown_dict[str(idx)] = markdown

    return markdown_dict

# %%
def delete_index():
    headers = {
        "api-key": os.getenv("SEARCH_KEY"),
        "Content-Type": "application/json",
    }
    response = requests.delete(
        os.getenv("SEARCH_ENDPOINT")
        + "/indexes/"
        + os.getenv("SEARCH_INDEX_NAME")
        + "?api-version=2020-06-30",
        headers=headers,
    )
    return response.status_code == 204


def check_index_deleted():
    headers = {
        "api-key": os.getenv("SEARCH_KEY"),
    }
    response = requests.get(
        os.getenv("SEARCH_ENDPOINT")
        + "/indexes/"
        + os.getenv("SEARCH_INDEX_NAME")
        + "?api-version=2020-06-30",
        headers=headers,
    )
    return response.status_code == 404

# %%
def init_acs():
    acs = AzureSearch(
        azure_search_endpoint=os.getenv("SEARCH_ENDPOINT"),
        azure_search_key=os.getenv("SEARCH_KEY"),
        index_name=os.getenv("SEARCH_INDEX_NAME"),
        embedding_function=embeddings.embed_query,
        fields=[
            SimpleField(
                name=FIELDS_ID,
                type=SearchFieldDataType.String,
                key=True,
                filterable=True,
            ),
            SearchableField(
                name=FIELDS_CONTENT,
                type=SearchFieldDataType.String,
                analyzer_name="nl.lucene",
            ),
            SearchField(
                name=FIELDS_CONTENT_VECTOR,
                type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
                searchable=True,
                vector_search_dimensions=1536,
                vector_search_profile_name="myHnswProfile",
            ),
            SearchableField(
                name=FIELDS_METADATA,
                type=SearchFieldDataType.String,
                analyzer_name="nl.lucene",
            ),
            SimpleField(
                name="title",
                type=SearchFieldDataType.String,
                key=False,
                filterable=True,
                sortable=True,
                facetable=True,
            ),
            SimpleField(
                name="page",
                type=SearchFieldDataType.String,
                key=False,
                filterable=True,
                sortable=True,
                facetable=True,
            ),
        ],
    )
    return acs

# %%
import pandas as pd

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df
#
# NameError: name 'df' is not defined

# %%
# AI SEARCH DATABASE ON FULL TEXT ECLI RECHTSPRAAK
acs = init_acs()

params = {
    "splitter": "TokenTextSplitter",
    "encoding_name": "cl100k_base",
    "chunk_size": 20480,
    "chunk_overlap": 2048,
}
token_splitter = TokenTextSplitter(
    encoding_name=params["encoding_name"],
    chunk_size=params["chunk_size"],
    chunk_overlap=params["chunk_overlap"],
)

for df_name in [
    "rechtspraak_metadata_2020.xlsx",
    "rechtspraak_metadata_2021.xlsx",
    "rechtspraak_metadata_2022.xlsx",
    "rechtspraak_metadata_2023.xlsx",
    "rechtspraak_metadata_2024.xlsx",
]:
    print(df_name)
    df = pd.read_excel(df_name)
    documents = []
    for index, row in df.iterrows():
        ecli = row["ecli"]
        fulltext = row["full_text"]

        chunks = token_splitter.split_text(fulltext)
        print(f"{ecli}: {len(chunks)}")
        for idx, chunk in enumerate(chunks):
            doc = Document(
                page_content=chunk,
                metadata={"title": ecli, "chunk_index": idx},
            )
            documents.append(doc.copy())

    # ADD ALL CHUNKS TO ACS
    acs.add_documents(documents)
    print("Creation of new index succesfull.")
# Out:
# rechtspraak_metadata_2020.xlsx
# ECLI:NL:RVS:2020:5: 7
# ECLI:NL:GHARL:2020:214: 5
# ECLI:NL:GHARL:2020:216: 5
# ECLI:NL:GHARL:2020:220: 4
# ECLI:NL:GHARL:2020:219: 4
# ECLI:NL:HR:2020:54: 1
# ECLI:NL:RBLIM:2020:401: 5
# ECLI:NL:RVS:2020:252: 2
# ECLI:NL:CRVB:2020:241: 3
# ECLI:NL:RBNNE:2020:430: 3
# ECLI:NL:RBOVE:2020:376: 3
# ECLI:NL:RBROT:2020:904: 8
# ECLI:NL:RVS:2020:383: 2
# ECLI:NL:GHARL:2020:1106: 4
# ECLI:NL:HR:2020:250: 1
# ECLI:NL:RBNNE:2020:724: 2
# ECLI:NL:RBOVE:2020:837: 10
# ECLI:NL:RVS:2020:593: 3
# ECLI:NL:CBB:2020:126: 6
# ECLI:NL:CRVB:2020:537: 3
# ECLI:NL:GHSHE:2020:888: 11
# ECLI:NL:HR:2020:424: 1
# ECLI:NL:CBB:2020:176: 3
# ECLI:NL:GHSHE:2020:974: 2
# ECLI:NL:OGEAC:2020:57: 3
# ECLI:NL:CBB:2020:163: 11
# ECLI:NL:CRVB:2020:678: 2
# ECLI:NL:CRVB:2020:680: 4
# ECLI:NL:CRVB:2020:744: 2
# ECLI:NL:GHSHE:2020:1079: 3
# ECLI:NL:CRVB:2020:763: 5
# ECLI:NL:CBB:2020:210: 2
# ECLI:NL:RBNNE:2020:1441: 2
# ECLI:NL:RBNHO:2020:2533: 6
# ECLI:NL:RBROT:2020:2985: 4
# ECLI:NL:OGEAA:2020:193: 6
# ECLI:NL:HR:2020:588: 1
# ECLI:NL:RBNHO:2020:2651: 2
# ECLI:NL:HR:2020:606: 1
# ECLI:NL:OGEAA:2020:125: 2
# ECLI:NL:RBROT:2020:3942: 3
# ECLI:NL:CRVB:2020:942: 4
# ECLI:NL:CRVB:2020:926: 4
# ECLI:NL:CBB:2020:250: 2
# ECLI:NL:CBB:2020:255: 4
# ECLI:NL:GHDHA:2020:760: 11
# ECLI:NL:CBB:2020:254: 3
# ECLI:NL:RBDHA:2020:3532: 6
# ECLI:NL:RBOBR:2020:2304: 2
# ECLI:NL:CBB:2020:295: 4
# ECLI:NL:RVS:2020:1126: 3
# ECLI:NL:RVS:2020:1098: 3
# ECLI:NL:RBDHA:2020:5080: 11
# ECLI:NL:CBB:2020:310: 1
# ECLI:NL:RBROT:2020:3962: 3
# ECLI:NL:ORBAACM:2020:12: 1
# ECLI:NL:RBDHA:2020:4107: 3
# ECLI:NL:RBNHO:2020:3287: 3
# ECLI:NL:RBGEL:2020:2483: 2
# ECLI:NL:RBNHO:2020:3193: 2
# ECLI:NL:RBAMS:2020:2595: 7
# ECLI:NL:RBAMS:2020:2807: 2
# ECLI:NL:RBAMS:2020:2658: 2
# ECLI:NL:RBROT:2020:4849: 2
# ECLI:NL:RBROT:2020:4850: 3
# ECLI:NL:OGEAC:2020:113: 2
# ECLI:NL:GHARL:2020:3675: 8
# ECLI:NL:GHARL:2020:3748: 4
# ECLI:NL:RBDHA:2020:6609: 3
# ECLI:NL:GHSHE:2020:1527: 5
# ECLI:NL:GHDHA:2020:871: 7
# ECLI:NL:RBAMS:2020:2584: 2
# ECLI:NL:GHARL:2020:4150: 4
# ECLI:NL:CBB:2020:344: 7
# ECLI:NL:RBLIM:2020:4254: 7
# ECLI:NL:RVS:2020:1246: 2
# ECLI:NL:RBROT:2020:4617: 3
# ECLI:NL:RBZWB:2020:2279: 1
# ECLI:NL:GHARL:2020:3942: 4
# ECLI:NL:RBROT:2020:4939: 3
# ECLI:NL:RBAMS:2020:2718: 6
# ECLI:NL:GHARL:2020:4082: 3
# ECLI:NL:GHARL:2020:4081: 5
# ECLI:NL:RBDHA:2020:5089: 1
# ECLI:NL:OGAACMB:2020:47: 4
# ECLI:NL:RBMNE:2020:2114: 4
# ECLI:NL:GHDHA:2020:978: 8
# ECLI:NL:RBZWB:2020:2430: 6
# ECLI:NL:RBDHA:2020:5271: 3
# ECLI:NL:RBNNE:2020:2078: 6
# ECLI:NL:RVS:2020:1394: 2
# ECLI:NL:GHAMS:2020:1662: 2
# ECLI:NL:RBZWB:2020:2661: 4
# ECLI:NL:RBNHO:2020:4528: 5
# ECLI:NL:RBNNE:2020:2226: 3
# ECLI:NL:RBROT:2020:5680: 2
# ECLI:NL:RBMNE:2020:2358: 4
# ECLI:NL:RBOBR:2020:3177: 4
# ECLI:NL:HR:2020:1173: 1
# ECLI:NL:HR:2020:1173: 1
# ECLI:NL:RBDHA:2020:6137: 7
# ECLI:NL:CRVB:2020:1397: 2
# ECLI:NL:RBNNE:2020:2484: 6
# ECLI:NL:RBDHA:2020:6124: 4
# ECLI:NL:GHSHE:2020:2033: 5
# ECLI:NL:RBAMS:2020:3378: 8
# ECLI:NL:RVS:2020:1662: 3
# ECLI:NL:CRVB:2020:1526: 2
# ECLI:NL:GHARL:2020:5612: 2
# ECLI:NL:RBNHO:2020:5593: 4
# ECLI:NL:RBROT:2020:6677: 3
# ECLI:NL:GHARL:2020:5898: 3
# ECLI:NL:RBZWB:2020:3327: 1
# ECLI:NL:RVS:2020:1858: 2
# ECLI:NL:RBOBR:2020:3751: 7
# ECLI:NL:GHDHA:2020:1351: 6
# ECLI:NL:CRVB:2020:1768: 2
# ECLI:NL:RBLIM:2020:5938: 7
# ECLI:NL:GHAMS:2020:2284: 2
# ECLI:NL:RVS:2020:1915: 2
# ECLI:NL:RVS:2020:1893: 4
# ECLI:NL:RBDHA:2020:10829: 4
# ECLI:NL:CBB:2020:550: 2
# ECLI:NL:CRVB:2020:1902: 3
# ECLI:NL:CRVB:2020:1950: 4
# ECLI:NL:RBZWB:2020:3862: 11
# ECLI:NL:CRVB:2020:1947: 4
# ECLI:NL:RBOBR:2020:4066: 9
# ECLI:NL:RBNHO:2020:6638: 4
# ECLI:NL:HR:2020:1326: 1
# ECLI:NL:RBDHA:2020:8422: 2
# ECLI:NL:RBOVE:2020:2842: 9
# ECLI:NL:CBB:2020:594: 4
# ECLI:NL:CBB:2020:583: 4
# ECLI:NL:CRVB:2020:2075: 3
# ECLI:NL:CRVB:2020:2052: 3
# ECLI:NL:CRVB:2020:2077: 3
# ECLI:NL:GHSHE:2020:2721: 2
# ECLI:NL:RBGEL:2020:4565: 5
# ECLI:NL:RBNHO:2020:7136: 6
# ECLI:NL:RBDHA:2020:9050: 3
# ECLI:NL:GHAMS:2020:2446: 5
# ECLI:NL:RVS:2020:2172: 2
# ECLI:NL:RVS:2020:2147: 1
# ECLI:NL:RBNNE:2020:3122: 10
# ECLI:NL:RBLIM:2020:6823: 6
# ECLI:NL:RBNHO:2020:7097: 11
# ECLI:NL:GHARL:2020:7352: 4
# ECLI:NL:RBNNE:2020:3216: 3
# ECLI:NL:OGAACMB:2020:69: 5
# ECLI:NL:OGHACMB:2020:204: 7
# ECLI:NL:RBNNE:2020:3304: 6
# ECLI:NL:RBGEL:2020:4974: 2
# ECLI:NL:HR:2020:1475: 1
# ECLI:NL:RBNHO:2020:7644: 6
# ECLI:NL:GHDHA:2020:1677: 3
# ECLI:NL:RVS:2020:2350: 2
# ECLI:NL:RBROT:2020:9518: 7
# ECLI:NL:RVS:2020:2359: 3
# ECLI:NL:CRVB:2020:2427: 4
# ECLI:NL:RVS:2020:2409: 1
# ECLI:NL:CRVB:2020:2475: 3
# ECLI:NL:RBZWB:2020:4995: 4
# ECLI:NL:RBAMS:2020:5431: 3
# ECLI:NL:RBAMS:2020:5440: 2
# ECLI:NL:GHARL:2020:9332: 4
# ECLI:NL:CRVB:2020:2511: 6
# ECLI:NL:RBOBR:2020:5064: 5
# ECLI:NL:HR:2020:1653: 1
# ECLI:NL:RBAMS:2020:5201: 4
# ECLI:NL:CBB:2020:759: 4
# ECLI:NL:OGEAA:2020:430: 2
# ECLI:NL:RBDHA:2020:10949: 3
# ECLI:NL:CRVB:2020:2641: 3
# ECLI:NL:RBROT:2020:9768: 4
# ECLI:NL:GHARL:2020:8892: 6
# ECLI:NL:CRVB:2020:2681: 1
# ECLI:NL:RVS:2020:2641: 6
# ECLI:NL:GHAMS:2020:2911: 2
# ECLI:NL:CRVB:2020:2684: 3
# ECLI:NL:GHAMS:2020:2979: 5
# ECLI:NL:RBDHA:2020:11334: 3
# ECLI:NL:CRVB:2020:2762: 1
# ECLI:NL:GHARL:2020:9320: 8
# ECLI:NL:RBMNE:2020:4922: 5
# ECLI:NL:CRVB:2020:2809: 3
# ECLI:NL:RVS:2020:2744: 6
# ECLI:NL:HR:2020:1825: 1
# ECLI:NL:GHARL:2020:9685: 4
# ECLI:NL:CBB:2020:862: 5
# ECLI:NL:RBMNE:2020:5188: 5
# ECLI:NL:RBROT:2020:10973: 4
# ECLI:NL:RVS:2020:2858: 4
# ECLI:NL:RBOBR:2020:5989: 5
# ECLI:NL:HR:2020:1920: 1
# ECLI:NL:RBAMS:2020:6047: 4
# ECLI:NL:RBGEL:2020:6462: 5
# ECLI:NL:GHARL:2020:10285: 6
# ECLI:NL:GHARL:2020:10279: 10
# ECLI:NL:CRVB:2020:3138: 3
# ECLI:NL:RBMNE:2020:5486: 4
# ECLI:NL:RBNHO:2020:10958: 5
# ECLI:NL:RVS:2020:2968: 4
# ECLI:NL:CRVB:2020:3195: 2
# ECLI:NL:RBZWB:2020:6380: 3
# ECLI:NL:CRVB:2020:3221: 3
# ECLI:NL:GHDHA:2020:2493: 11
# ECLI:NL:RBNNE:2020:4621: 4
# ECLI:NL:CRVB:2020:3449: 2
# ECLI:NL:GHAMS:2020:3673: 8
# ECLI:NL:RBOBR:2020:6576: 9
# ECLI:NL:CRVB:2020:3485: 5
# ECLI:NL:RBZWB:2020:6787: 2
# ECLI:NL:RBNHO:2020:11258: 2
# ECLI:NL:RBOVE:2020:4598: 12
# Creation of new index succesfull.
# rechtspraak_metadata_2021.xlsx
# ECLI:NL:RBDHA:2021:629: 1
# ECLI:NL:GHARL:2021:76: 3
# ECLI:NL:RBNNE:2021:20: 5
# ECLI:NL:RBDHA:2021:222: 1
# ECLI:NL:RBOVE:2021:221: 5
# ECLI:NL:CRVB:2021:24: 3
# ECLI:NL:RBDHA:2021:224: 4
# ECLI:NL:RBDHA:2021:78: 10
# ECLI:NL:RBDHA:2021:212: 2
# ECLI:NL:RVS:2021:50: 4
# ECLI:NL:RBOBR:2021:162: 11
# ECLI:NL:RBDHA:2021:219: 11
# ECLI:NL:GHSHE:2021:87: 5
# ECLI:NL:GHARL:2021:581: 2
# ECLI:NL:GHARL:2021:589: 5
# ECLI:NL:GHARL:2021:590: 5
# ECLI:NL:RBMNE:2021:145: 8
# ECLI:NL:CRVB:2021:180: 4
# ECLI:NL:RBDHA:2021:467: 8
# ECLI:NL:HR:2021:133: 1
# ECLI:NL:CBB:2021:111: 2
# ECLI:NL:RBDHA:2021:857: 4
# ECLI:NL:RVS:2021:200: 1
# ECLI:NL:GHDHA:2021:150: 10
# ECLI:NL:RBMNE:2021:406: 7
# ECLI:NL:CBB:2021:130: 4
# ECLI:NL:GHARL:2021:1194: 4
# ECLI:NL:RBAMS:2021:425: 4
# ECLI:NL:RBMNE:2021:567: 2
# ECLI:NL:RBLIM:2021:1378: 3
# ECLI:NL:RVS:2021:261: 2
# ECLI:NL:CRVB:2021:276: 5
# ECLI:NL:RBOVE:2021:645: 4
# ECLI:NL:GHARL:2021:1404: 3
# ECLI:NL:RBLIM:2021:1374: 4
# ECLI:NL:GHAMS:2021:411: 1
# ECLI:NL:GHAMS:2021:411: 1
# ECLI:NL:RBDHA:2021:1626: 4
# ECLI:NL:HR:2021:283: 1
# ECLI:NL:CRVB:2021:428: 3
# ECLI:NL:HR:2021:318: 1
# ECLI:NL:CBB:2021:202: 5
# ECLI:NL:GHARL:2021:1810: 6
# ECLI:NL:RBOVE:2021:934: 4
# ECLI:NL:RVS:2021:493: 3
# ECLI:NL:RVS:2021:488: 4
# ECLI:NL:RBGEL:2021:1202: 9
# ECLI:NL:CBB:2021:268: 7
# ECLI:NL:RBNHO:2021:2170: 7
# ECLI:NL:GHARL:2021:2620: 4
# ECLI:NL:RBNHO:2021:2170: 7
# ECLI:NL:RBZWB:2021:1330: 4
# ECLI:NL:GHSHE:2021:907: 2
# ECLI:NL:CBB:2021:358: 5
# ECLI:NL:GHARL:2021:3084: 4
# ECLI:NL:GHARL:2021:3085: 7
# ECLI:NL:CBB:2021:352: 6
# ECLI:NL:HR:2021:496: 2
# ECLI:NL:RVS:2021:730: 2
# ECLI:NL:RBNNE:2021:1168: 2
# ECLI:NL:GHAMS:2021:983: 3
# ECLI:NL:RBOVE:2021:1507: 4
# ECLI:NL:CRVB:2021:820: 3
# ECLI:NL:RBNHO:2021:3101: 6
# ECLI:NL:HR:2021:615: 1
# ECLI:NL:HR:2021:616: 1
# ECLI:NL:RBDHA:2021:3835: 2
# ECLI:NL:GHSHE:2021:1241: 5
# ECLI:NL:RBAMS:2021:2000: 8
# ECLI:NL:HR:2021:661: 1
# ECLI:NL:GHARL:2021:4055: 2
# ECLI:NL:RVS:2021:899: 8
# ECLI:NL:RVS:2021:884: 1
# ECLI:NL:RBLIM:2021:3793: 11
# ECLI:NL:GHARL:2021:4190: 7
# ECLI:NL:RBROT:2021:5700: 6
# ECLI:NL:RVS:2021:975: 1
# ECLI:NL:RBMNE:2021:3394: 5
# ECLI:NL:HR:2021:711: 1
# ECLI:NL:RBNNE:2021:1786: 11
# ECLI:NL:RVS:2021:1039: 3
# ECLI:NL:GHARL:2021:4875: 4
# ECLI:NL:GHARL:2021:4818: 2
# ECLI:NL:CBB:2021:533: 6
# ECLI:NL:RBROT:2021:4697: 7
# ECLI:NL:CBB:2021:546: 4
# ECLI:NL:RBGEL:2021:2617: 5
# ECLI:NL:RBROT:2021:4902: 6
# ECLI:NL:RBDHA:2021:5724: 1
# ECLI:NL:CRVB:2021:1380: 2
# ECLI:NL:RVS:2021:1165: 4
# ECLI:NL:RBROT:2021:4931: 9
# ECLI:NL:RBDHA:2021:5721: 1
# ECLI:NL:CBB:2021:590: 5
# ECLI:NL:RVS:2021:1208: 2
# ECLI:NL:RBDHA:2021:5925: 5
# ECLI:NL:RBZWB:2021:2892: 4
# ECLI:NL:HR:2021:914: 1
# ECLI:NL:GHARL:2021:6026: 3
# ECLI:NL:RBMNE:2021:2645: 2
# ECLI:NL:HR:2021:971: 1
# ECLI:NL:RBDHA:2021:6368: 6
# ECLI:NL:RBDHA:2021:6493: 4
# ECLI:NL:CBB:2021:628: 6
# ECLI:NL:GHARL:2021:6127: 6
# ECLI:NL:RBDHA:2021:6630: 2
# ECLI:NL:GHARL:2021:6283: 4
# ECLI:NL:RBDHA:2021:6619: 11
# ECLI:NL:CBB:2021:650: 2
# ECLI:NL:RBDHA:2021:6946: 1
# ECLI:NL:RBDHA:2021:6631: 11
# ECLI:NL:RVS:2021:1382: 2
# ECLI:NL:HR:2021:1074: 1
# ECLI:NL:RBDHA:2021:7002: 2
# ECLI:NL:RBROT:2021:6459: 4
# ECLI:NL:RBNHO:2021:5665: 5
# ECLI:NL:RBAMS:2021:3544: 8
# ECLI:NL:RBZWB:2021:3489: 7
# ECLI:NL:RBMNE:2021:2941: 5
# ECLI:NL:RBNNE:2021:2887: 3
# ECLI:NL:RBDHA:2021:7538: 1
# ECLI:NL:RBZWB:2021:3534: 4
# ECLI:NL:CBB:2021:757: 3
# ECLI:NL:GHSHE:2021:2273: 3
# ECLI:NL:GHARL:2021:6948: 5
# ECLI:NL:GHSHE:2021:2338: 7
# ECLI:NL:GHDHA:2021:1409: 5
# ECLI:NL:GHSHE:2021:2345: 5
# ECLI:NL:RVS:2021:1648: 1
# ECLI:NL:RVS:2021:1691: 4
# ECLI:NL:RBROT:2021:7427: 4
# ECLI:NL:RBAMS:2021:3999: 6
# ECLI:NL:RVS:2021:1714: 1
# ECLI:NL:RBMNE:2021:3664: 12
# ECLI:NL:RBDHA:2021:8641: 4
# ECLI:NL:RBDHA:2021:9289: 4
# ECLI:NL:RBOVE:2021:3155: 4
# ECLI:NL:RBMNE:2021:4279: 2
# ECLI:NL:RBDHA:2021:8681: 3
# ECLI:NL:CBB:2021:810: 3
# ECLI:NL:RVS:2021:1778: 1
# ECLI:NL:CRVB:2021:2207: 2
# ECLI:NL:GHSHE:2021:2569: 2
# ECLI:NL:CBB:2021:829: 1
# ECLI:NL:RBOVE:2021:3274: 7
# ECLI:NL:RBDHA:2021:8949: 2
# ECLI:NL:OGHACMB:2021:307: 2
# ECLI:NL:RBROT:2021:8896: 2
# ECLI:NL:RVS:2021:1887: 2
# ECLI:NL:CRVB:2021:2128: 5
# ECLI:NL:RBZWB:2021:4276: 2
# ECLI:NL:RBNHO:2021:7639: 3
# ECLI:NL:RBNHO:2021:7411: 5
# ECLI:NL:GHAMS:2021:2641: 3
# ECLI:NL:RBROT:2021:8744: 3
# ECLI:NL:RBZWB:2021:4428: 2
# ECLI:NL:CRVB:2021:2255: 4
# ECLI:NL:RBROT:2021:8512: 5
# ECLI:NL:RBAMS:2021:6521: 11
# ECLI:NL:RBNHO:2021:7811: 7
# ECLI:NL:RBDHA:2021:10023: 2
# ECLI:NL:RBZWB:2021:4497: 4
# ECLI:NL:RBZWB:2021:4504: 7
# ECLI:NL:CRVB:2021:2308: 4
# ECLI:NL:RBROT:2021:9096: 5
# ECLI:NL:RBROT:2021:10072: 3
# ECLI:NL:HR:2021:1244: 4
# ECLI:NL:CRVB:2021:2359: 7
# ECLI:NL:CBB:2021:884: 5
# ECLI:NL:GHARL:2021:8671: 6
# ECLI:NL:RBZWB:2021:4587: 5
# ECLI:NL:RBROT:2021:9071: 5
# ECLI:NL:RBROT:2021:9053: 11
# ECLI:NL:RBZWB:2021:4721: 5
# ECLI:NL:RBZWB:2021:4708: 3
# ECLI:NL:RVS:2021:2128: 2
# ECLI:NL:RBZWB:2021:4728: 1
# ECLI:NL:HR:2021:1394: 1
# ECLI:NL:GHARL:2021:9123: 2
# ECLI:NL:RBDHA:2021:10654: 3
# ECLI:NL:RBZWB:2021:4849: 4
# ECLI:NL:RBROT:2021:9234: 6
# ECLI:NL:RBDHA:2021:10749: 3
# ECLI:NL:RBDHA:2021:10869: 5
# ECLI:NL:RBDHA:2021:10668: 4
# ECLI:NL:RBROT:2021:9329: 4
# ECLI:NL:RBDHA:2021:11124: 1
# ECLI:NL:GHARL:2021:9265: 5
# ECLI:NL:RBAMS:2021:5545: 5
# ECLI:NL:RBROT:2021:9493: 3
# ECLI:NL:RBGEL:2021:5177: 2
# ECLI:NL:HR:2021:1464: 1
# ECLI:NL:GHARL:2021:9565: 4
# ECLI:NL:GHARL:2021:9568: 8
# ECLI:NL:GHARL:2021:9569: 3
# ECLI:NL:CBB:2021:930: 4
# ECLI:NL:RBOVE:2021:3828: 3
# ECLI:NL:CBB:2021:952: 4
# ECLI:NL:RBMNE:2021:5046: 5
# ECLI:NL:CRVB:2021:2567: 1
# ECLI:NL:RVS:2021:2333: 3
# ECLI:NL:GHSHE:2021:3187: 5
# ECLI:NL:RBDHA:2021:11578: 11
# ECLI:NL:RBDHA:2021:11631: 4
# ECLI:NL:RVS:2021:2392: 9
# ECLI:NL:RBNNE:2021:4570: 5
# ECLI:NL:RBNHO:2021:9613: 8
# ECLI:NL:CRVB:2021:2716: 2
# ECLI:NL:HR:2021:1640: 1
# ECLI:NL:RBZWB:2021:5611: 1
# ECLI:NL:RBAMS:2021:6203: 3
# ECLI:NL:RBDHA:2021:12353: 1
# ECLI:NL:GHAMS:2021:3711: 3
# ECLI:NL:RBZWB:2021:5659: 2
# ECLI:NL:GHARL:2021:10445: 5
# ECLI:NL:RBROT:2021:11080: 2
# ECLI:NL:RBDHA:2021:12505: 1
# ECLI:NL:GHDHA:2021:2052: 8
# ECLI:NL:RBNHO:2021:10272: 3
# ECLI:NL:RBZWB:2021:5854: 5
# ECLI:NL:RBOBR:2021:6017: 8
# ECLI:NL:GHAMS:2021:3552: 3
# ECLI:NL:RVS:2021:2579: 4
# ECLI:NL:RBAMS:2021:6613: 3
# ECLI:NL:RBZWB:2021:5898: 3
# ECLI:NL:RBZWB:2021:5902: 1
# ECLI:NL:CRVB:2021:2874: 4
# ECLI:NL:RBNHO:2021:10653: 7
# ECLI:NL:RBNHO:2021:11155: 3
# ECLI:NL:RBOBR:2021:6102: 9
# ECLI:NL:RBOVE:2021:4371: 11
# ECLI:NL:RBLIM:2021:8793: 12
# ECLI:NL:RBLIM:2021:8796: 11
# ECLI:NL:RBZWB:2021:5976: 6
# ECLI:NL:RBDHA:2021:12976: 6
# ECLI:NL:RBZWB:2021:5975: 6
# ECLI:NL:RVS:2021:2664: 1
# ECLI:NL:RBAMS:2021:6880: 6
# ECLI:NL:HR:2021:1820: 1
# ECLI:NL:RBDHA:2021:13592: 4
# ECLI:NL:OGEAA:2021:575: 6
# ECLI:NL:CRVB:2021:3096: 2
# ECLI:NL:RBAMS:2021:7482: 11
# ECLI:NL:CBB:2021:1054: 3
# ECLI:NL:CRVB:2021:3064: 1
# ECLI:NL:RBZWB:2021:6285: 2
# ECLI:NL:RBROT:2021:12103: 3
# ECLI:NL:CRVB:2021:3091: 5
# ECLI:NL:RBZWB:2021:6282: 2
# ECLI:NL:CRVB:2021:3090: 2
# ECLI:NL:RBZWB:2021:6280: 2
# ECLI:NL:GHARL:2021:11362: 6
# ECLI:NL:RBROT:2021:12338: 8
# ECLI:NL:HR:2021:1904: 1
# ECLI:NL:RVS:2021:2807: 1
# ECLI:NL:RBDHA:2021:14339: 1
# ECLI:NL:CRVB:2021:3269: 2
# ECLI:NL:CRVB:2021:3264: 2
# ECLI:NL:GHARL:2021:11795: 3
# ECLI:NL:RVS:2021:2973: 1
# ECLI:NL:GHARL:2021:11939: 11
# ECLI:NL:RBROT:2021:13064: 7
# ECLI:NL:GHSHE:2021:3868: 1
# ECLI:NL:RBDHA:2021:15132: 6
# Creation of new index succesfull.
# rechtspraak_metadata_2022.xlsx
# ECLI:NL:CRVB:2022:6: 3
# ECLI:NL:RVS:2022:12: 1
# ECLI:NL:RBROT:2022:43: 2
# ECLI:NL:RVS:2022:26: 2
# ECLI:NL:RBNHO:2022:92: 6
# ECLI:NL:RBZWB:2022:131: 5
# ECLI:NL:GHARL:2022:910: 3
# ECLI:NL:RBMNE:2022:34: 9
# ECLI:NL:RBNHO:2022:141: 9
# ECLI:NL:RBMNE:2022:60: 8
# ECLI:NL:RBZWB:2022:142: 3
# ECLI:NL:GHARL:2022:244: 3
# ECLI:NL:GHARL:2022:361: 4
# ECLI:NL:RBDHA:2022:336: 1
# ECLI:NL:RBZWB:2022:272: 2
# ECLI:NL:RBROT:2022:313: 5
# ECLI:NL:RBZWB:2022:340: 1
# ECLI:NL:RBZWB:2022:347: 6
# ECLI:NL:RBDHA:2022:489: 4
# ECLI:NL:RBNHO:2022:499: 3
# ECLI:NL:CBB:2022:41: 6
# ECLI:NL:RBZWB:2022:336: 2
# ECLI:NL:RBZWB:2022:347: 6
# ECLI:NL:RBZWB:2022:425: 6
# ECLI:NL:RBDHA:2022:699: 8
# ECLI:NL:RBGEL:2022:476: 10
# ECLI:NL:RVS:2022:329: 2
# ECLI:NL:RBNHO:2022:921: 11
# ECLI:NL:RBMNE:2022:446: 4
# ECLI:NL:GHSHE:2022:300: 8
# ECLI:NL:RBOVE:2022:389: 5
# ECLI:NL:OGEAC:2022:15: 11
# ECLI:NL:CRVB:2022:333: 2
# ECLI:NL:RBNHO:2022:1506: 6
# ECLI:NL:OGEAA:2022:30: 2
# ECLI:NL:RBMNE:2022:490: 10
# ECLI:NL:RVS:2022:447: 4
# ECLI:NL:RVS:2022:466: 2
# ECLI:NL:RBZWB:2022:776: 5
# ECLI:NL:HR:2022:203: 1
# ECLI:NL:GHSHE:2022:515: 3
# ECLI:NL:HR:2022:225: 1
# ECLI:NL:GHDHA:2022:227: 8
# ECLI:NL:GHARL:2022:1407: 9
# ECLI:NL:CBB:2022:82: 4
# ECLI:NL:RBZWB:2022:938: 6
# ECLI:NL:RBROT:2022:1428: 4
# ECLI:NL:GHARL:2022:1581: 4
# ECLI:NL:RVS:2022:634: 4
# ECLI:NL:RBAMS:2022:1036: 8
# ECLI:NL:CRVB:2022:475: 3
# ECLI:NL:RBNHO:2022:2212: 5
# ECLI:NL:RVS:2022:708: 8
# ECLI:NL:RBNNE:2022:673: 3
# ECLI:NL:GHAMS:2022:730: 3
# ECLI:NL:RBROT:2022:1763: 3
# ECLI:NL:RBAMS:2022:1093: 7
# ECLI:NL:CRVB:2022:608: 4
# ECLI:NL:RBAMS:2022:1486: 9
# ECLI:NL:RBDHA:2022:2225: 1
# ECLI:NL:RBROT:2022:1825: 3
# ECLI:NL:RBDHA:2022:2324: 5
# ECLI:NL:GHARL:2022:2017: 3
# ECLI:NL:HR:2022:384: 1
# ECLI:NL:RBZWB:2022:1450: 2
# ECLI:NL:RBROT:2022:2357: 2
# ECLI:NL:CBB:2022:125: 3
# ECLI:NL:RVS:2022:855: 5
# ECLI:NL:RBROT:2022:2108: 2
# ECLI:NL:RBNHO:2022:2617: 11
# ECLI:NL:RVS:2022:948: 6
# ECLI:NL:CRVB:2022:722: 4
# ECLI:NL:RBLIM:2022:2618: 12
# ECLI:NL:RBROT:2022:2373: 4
# ECLI:NL:RBZWB:2022:1670: 6
# ECLI:NL:OGHACMB:2022:23: 6
# ECLI:NL:RBDHA:2022:3417: 1
# ECLI:NL:RBDHA:2022:3413: 4
# ECLI:NL:RBROT:2022:2663: 2
# ECLI:NL:GHARL:2022:2778: 4
# ECLI:NL:GHSHE:2022:1170: 6
# ECLI:NL:RBOVE:2022:1042: 10
# ECLI:NL:GHAMS:2022:1140: 2
# ECLI:NL:GHARL:2022:2999: 5
# ECLI:NL:RBROT:2022:3138: 7
# ECLI:NL:RBZWB:2022:2062: 5
# ECLI:NL:GHARL:2022:2999: 5
# ECLI:NL:GHARL:2022:2995: 3
# ECLI:NL:HR:2022:605: 1
# ECLI:NL:RBAMS:2022:2377: 2
# ECLI:NL:RBGEL:2022:2200: 5
# ECLI:NL:RBAMS:2022:2358: 3
# ECLI:NL:RBDHA:2022:4095: 4
# ECLI:NL:RBDHA:2022:4275: 1
# ECLI:NL:RBNHO:2022:4017: 2
# ECLI:NL:RBZWB:2022:2463: 5
# ECLI:NL:RBDHA:2022:4591: 2
# ECLI:NL:RBZWB:2022:2699: 4
# ECLI:NL:CRVB:2022:1153: 2
# ECLI:NL:GHAMS:2022:1455: 4
# ECLI:NL:OGEAM:2022:37: 3
# ECLI:NL:OGEAM:2022:38: 5
# ECLI:NL:CBB:2022:249: 2
# ECLI:NL:GHARL:2022:4003: 11
# ECLI:NL:RBROT:2022:3910: 3
# ECLI:NL:GHARL:2022:4287: 5
# ECLI:NL:RBZWB:2022:2769: 11
# ECLI:NL:RBDHA:2022:5169: 3
# ECLI:NL:RVS:2022:1506: 1
# ECLI:NL:GHAMS:2022:1592: 11
# ECLI:NL:RVS:2022:1487: 5
# ECLI:NL:RVS:2022:1472: 2
# ECLI:NL:RBDHA:2022:5919: 5
# ECLI:NL:RBMNE:2022:2033: 4
# ECLI:NL:RBZWB:2022:2899: 4
# ECLI:NL:RBOVE:2022:1631: 7
# ECLI:NL:RBZWB:2022:2965: 3
# ECLI:NL:RBROT:2022:4420: 4
# ECLI:NL:RBNHO:2022:12101: 2
# ECLI:NL:RBNHO:2022:12116: 3
# ECLI:NL:RBMNE:2022:2460: 4
# ECLI:NL:RBZWB:2022:3051: 5
# ECLI:NL:RBZWB:2022:3048: 5
# ECLI:NL:RBDHA:2022:5765: 1
# ECLI:NL:RBAMS:2022:3211: 3
# ECLI:NL:RVS:2022:1669: 1
# ECLI:NL:RVS:2022:1639: 1
# ECLI:NL:RBROT:2022:4482: 1
# ECLI:NL:GHARL:2022:4860: 11
# ECLI:NL:OGEAC:2022:151: 3
# ECLI:NL:CBB:2022:303: 3
# ECLI:NL:GHARL:2022:4865: 10
# ECLI:NL:RBAMS:2022:3450: 10
# ECLI:NL:CBB:2022:326: 3
# ECLI:NL:RBDHA:2022:6057: 2
# ECLI:NL:RBDHA:2022:6058: 4
# ECLI:NL:RBLIM:2022:4808: 4
# ECLI:NL:RVS:2022:1755: 4
# ECLI:NL:RBDHA:2022:6005: 5
# ECLI:NL:RBZWB:2022:3434: 2
# ECLI:NL:RBDHA:2022:6541: 3
# ECLI:NL:RBZWB:2022:3151: 2
# ECLI:NL:RBOVE:2022:1846: 11
# ECLI:NL:RBAMS:2022:3593: 5
# ECLI:NL:RBZWB:2022:3494: 1
# ECLI:NL:RBZWB:2022:3539: 2
# ECLI:NL:RBZWB:2022:3591: 7
# ECLI:NL:RVS:2022:1869: 3
# ECLI:NL:RBDHA:2022:6649: 4
# ECLI:NL:CRVB:2022:1512: 4
# ECLI:NL:RBNHO:2022:5825: 4
# ECLI:NL:RBZWB:2022:3691: 2
# ECLI:NL:HR:2022:1054: 1
# ECLI:NL:RBDHA:2022:7179: 2
# ECLI:NL:RBDHA:2022:6665: 4
# ECLI:NL:RBDHA:2022:6658: 3
# ECLI:NL:RBROT:2022:6066: 4
# ECLI:NL:RBROT:2022:6065: 6
# ECLI:NL:CBB:2022:370: 4
# ECLI:NL:CRVB:2022:1543: 2
# ECLI:NL:RBOVE:2022:2039: 8
# ECLI:NL:GHARL:2022:6296: 7
# ECLI:NL:RBROT:2022:6027: 10
# ECLI:NL:RVS:2022:2079: 5
# ECLI:NL:RBZWB:2022:4037: 1
# ECLI:NL:RBROT:2022:5493: 3
# ECLI:NL:RBZWB:2022:4098: 7
# ECLI:NL:CBB:2022:434: 3
# ECLI:NL:CBB:2022:482: 3
# ECLI:NL:RBNHO:2022:6575: 11
# ECLI:NL:RBROT:2022:6549: 4
# ECLI:NL:RBNNE:2022:2858: 6
# ECLI:NL:RBGEL:2022:4696: 4
# ECLI:NL:RBDHA:2022:8076: 2
# ECLI:NL:CBB:2022:512: 1
# ECLI:NL:RVS:2022:2346: 1
# ECLI:NL:RBAMS:2022:4655: 5
# ECLI:NL:RVS:2022:2398: 4
# ECLI:NL:GHSHE:2022:2826: 7
# ECLI:NL:CRVB:2022:1825: 3
# ECLI:NL:CRVB:2022:1832: 5
# ECLI:NL:CRVB:2022:1904: 4
# ECLI:NL:RVS:2022:2380: 4
# ECLI:NL:CRVB:2022:1873: 3
# ECLI:NL:RBOBR:2022:3492: 6
# ECLI:NL:RBROT:2022:7238: 11
# ECLI:NL:RBZWB:2022:4958: 6
# ECLI:NL:RBDHA:2022:8527: 5
# ECLI:NL:RBZWB:2022:4936: 2
# ECLI:NL:RVS:2022:2510: 2
# ECLI:NL:RBZWB:2022:5124: 5
# ECLI:NL:RBNHO:2022:12319: 2
# ECLI:NL:RBMNE:2022:3516: 10
# ECLI:NL:RBGEL:2022:5102: 11
# ECLI:NL:HR:2022:1133: 1
# ECLI:NL:RBDHA:2022:8815: 5
# ECLI:NL:RBOVE:2022:2518: 5
# ECLI:NL:RBNHO:2022:7861: 2
# ECLI:NL:GHARL:2022:7668: 5
# ECLI:NL:GHDHA:2022:1595: 5
# ECLI:NL:CBB:2022:586: 3
# ECLI:NL:RBZWB:2022:4880: 3
# ECLI:NL:RBDHA:2022:9059: 2
# ECLI:NL:RBNNE:2022:3311: 11
# ECLI:NL:GHSHE:2022:3143: 8
# ECLI:NL:RBOBR:2022:3912: 5
# ECLI:NL:RBDHA:2022:9508: 1
# ECLI:NL:RBDHA:2022:9646: 1
# ECLI:NL:HR:2022:1210: 1
# ECLI:NL:HR:2022:1212: 1
# ECLI:NL:RBZWB:2022:5423: 4
# ECLI:NL:CBB:2022:626: 1
# ECLI:NL:RBDHA:2022:9594: 6
# ECLI:NL:RBDHA:2022:9651: 6
# ECLI:NL:CRVB:2022:2041: 1
# ECLI:NL:RBMNE:2022:3774: 4
# ECLI:NL:CBB:2022:698: 2
# ECLI:NL:RBOVE:2022:2701: 2
# ECLI:NL:RBOVE:2022:2706: 11
# ECLI:NL:HR:2022:1352: 1
# ECLI:NL:OGHACMB:2022:99: 5
# ECLI:NL:GHAMS:2022:2824: 5
# ECLI:NL:GHAMS:2022:2850: 4
# ECLI:NL:RBDHA:2022:10324: 1
# ECLI:NL:RBROT:2022:8255: 4
# ECLI:NL:RBAMS:2022:5666: 4
# ECLI:NL:RVS:2022:2856: 5
# ECLI:NL:RBOBR:2022:4155: 7
# ECLI:NL:RVS:2022:2925: 4
# ECLI:NL:RBZWB:2022:5951: 6
# ECLI:NL:RBNNE:2022:3764: 4
# ECLI:NL:RBDHA:2022:10547: 11
# ECLI:NL:CBB:2022:714: 3
# ECLI:NL:GHARL:2022:8971: 2
# ECLI:NL:RVS:2022:2983: 2
# ECLI:NL:GHDHA:2022:2089: 2
# ECLI:NL:RBROT:2022:8834: 5
# ECLI:NL:RBDHA:2022:11066: 1
# ECLI:NL:RBDHA:2022:10820: 3
# ECLI:NL:CRVB:2022:2298: 5
# ECLI:NL:HR:2022:1542: 1
# ECLI:NL:HR:2022:1549: 1
# ECLI:NL:HR:2022:1549: 1
# ECLI:NL:RBDHA:2022:11421: 1
# ECLI:NL:RBDHA:2022:11422: 4
# ECLI:NL:CBB:2022:732: 3
# ECLI:NL:RBDHA:2022:11555: 5
# ECLI:NL:RBROT:2022:9590: 8
# ECLI:NL:RBOVE:2022:3369: 10
# ECLI:NL:RVS:2022:3208: 3
# ECLI:NL:RBDHA:2022:11631: 2
# ECLI:NL:RBDHA:2022:11839: 3
# ECLI:NL:RBDHA:2022:12068: 3
# ECLI:NL:RBDHA:2022:12207: 2
# ECLI:NL:RVS:2022:3356: 1
# ECLI:NL:RBDHA:2022:12599: 2
# ECLI:NL:RBNNE:2022:4746: 5
# ECLI:NL:GHSHE:2022:4010: 8
# ECLI:NL:RBAMS:2022:6846: 4
# ECLI:NL:HR:2022:1751: 1
# ECLI:NL:GHSHE:2022:4110: 11
# ECLI:NL:CBB:2022:779: 4
# ECLI:NL:RBOVE:2022:3671: 2
# ECLI:NL:RVS:2022:3598: 4
# ECLI:NL:RVS:2022:3616: 10
# ECLI:NL:RBZWB:2022:7501: 11
# ECLI:NL:CRVB:2022:2685: 4
# ECLI:NL:RBZWB:2022:7584: 7
# ECLI:NL:RBZWB:2022:7660: 4
# ECLI:NL:GHARL:2022:10831: 4
# ECLI:NL:GHARL:2022:10828: 4
# ECLI:NL:RBDHA:2022:13944: 2
# ECLI:NL:RBNNE:2022:4871: 11
# ECLI:NL:HR:2022:1923: 1
# ECLI:NL:RBDHA:2022:15456: 2
# ECLI:NL:RBNHO:2022:11907: 8
# Creation of new index succesfull.
# rechtspraak_metadata_2023.xlsx
# ECLI:NL:CRVB:2023:5: 4
# ECLI:NL:RBZWB:2023:33: 2
# ECLI:NL:RBAMS:2023:51: 5
# ECLI:NL:RBAMS:2023:118: 2
# ECLI:NL:RBDHA:2023:444: 4
# ECLI:NL:OGEAC:2023:3: 2
# ECLI:NL:RVS:2023:151: 3
# ECLI:NL:CBB:2023:10: 1
# ECLI:NL:RBZWB:2023:173: 1
# ECLI:NL:RBOVE:2023:194: 5
# ECLI:NL:RBGEL:2023:375: 11
# ECLI:NL:GHARL:2023:623: 5
# ECLI:NL:RBDHA:2023:785: 2
# ECLI:NL:GHSHE:2023:222: 2
# ECLI:NL:RBOVE:2023:330: 5
# ECLI:NL:RVS:2023:289: 4
# ECLI:NL:RBLIM:2023:619: 8
# ECLI:NL:RBZWB:2023:474: 1
# ECLI:NL:RBDHA:2023:907: 1
# ECLI:NL:CRVB:2023:203: 2
# ECLI:NL:RBDHA:2023:969: 2
# ECLI:NL:RBDHA:2023:1360: 2
# ECLI:NL:RBZWB:2023:769: 3
# ECLI:NL:RBAMS:2023:737: 2
# ECLI:NL:RBDHA:2023:1102: 2
# ECLI:NL:HR:2023:213: 1
# ECLI:NL:RBDHA:2023:1789: 2
# ECLI:NL:GHDHA:2023:225: 5
# ECLI:NL:RBDHA:2023:1692: 5
# ECLI:NL:RBOBR:2023:610: 11
# ECLI:NL:ORBAACM:2023:6: 3
# ECLI:NL:RBZWB:2023:1108: 7
# ECLI:NL:RBZWB:2023:1163: 5
# ECLI:NL:GHAMS:2023:449: 2
# ECLI:NL:RVS:2023:726: 3
# ECLI:NL:RBDHA:2023:2109: 1
# ECLI:NL:RBDHA:2023:2114: 3
# ECLI:NL:RBROT:2023:1411: 6
# ECLI:NL:RBOVE:2023:656: 7
# ECLI:NL:RBGEL:2023:945: 2
# ECLI:NL:GHSHE:2023:650: 1
# ECLI:NL:RBDHA:2023:2416: 3
# ECLI:NL:RBNNE:2023:855: 11
# ECLI:NL:RBDHA:2023:2617: 2
# ECLI:NL:RBNHO:2023:1903: 6
# ECLI:NL:RBDHA:2023:2607: 1
# ECLI:NL:RBDHA:2023:3044: 3
# ECLI:NL:RBNHO:2023:2053: 9
# ECLI:NL:GHARL:2023:2096: 11
# ECLI:NL:GHARL:2023:2097: 6
# ECLI:NL:RBDHA:2023:3012: 4
# ECLI:NL:RVS:2023:997: 2
# ECLI:NL:GHARL:2023:2219: 10
# ECLI:NL:GHARL:2023:2165: 4
# ECLI:NL:GHARL:2023:2163: 7
# ECLI:NL:HR:2023:367: 1
# ECLI:NL:CBB:2023:131: 6
# ECLI:NL:RBDHA:2023:3555: 1
# ECLI:NL:RBDHA:2023:3656: 1
# ECLI:NL:RBDHA:2023:3654: 1
# ECLI:NL:RBGEL:2023:1584: 9
# ECLI:NL:RBDHA:2023:3703: 3
# ECLI:NL:RBDHA:2023:4172: 1
# ECLI:NL:RVS:2023:1111: 1
# ECLI:NL:RBDHA:2023:3960: 2
# ECLI:NL:RBDHA:2023:4250: 2
# ECLI:NL:RBZWB:2023:2098: 8
# ECLI:NL:RBDHA:2023:4677: 4
# ECLI:NL:RVS:2023:1303: 1
# ECLI:NL:RBDHA:2023:4591: 4
# ECLI:NL:RBDHA:2023:4694: 11
# ECLI:NL:RBMNE:2023:1590: 11
# ECLI:NL:RBZWB:2023:2338: 4
# ECLI:NL:GHAMS:2023:847: 3
# ECLI:NL:RBDHA:2023:5081: 3
# ECLI:NL:CBB:2023:182: 6
# ECLI:NL:RBDHA:2023:5240: 1
# ECLI:NL:RBDHA:2023:5412: 5
# ECLI:NL:CBB:2023:196: 3
# ECLI:NL:RBDHA:2023:6007: 2
# ECLI:NL:RVS:2023:1530: 10
# ECLI:NL:RBDHA:2023:5896: 2
# ECLI:NL:RBDHA:2023:6007: 2
# ECLI:NL:RBDHA:2023:6010: 2
# ECLI:NL:RBDHA:2023:5811: 2
# ECLI:NL:RBDHA:2023:5901: 2
# ECLI:NL:CBB:2023:211: 3
# ECLI:NL:RBNHO:2023:3856: 6
# ECLI:NL:RVS:2023:1608: 1
# ECLI:NL:RVS:2023:1617: 1
# ECLI:NL:RVS:2023:1621: 1
# ECLI:NL:RVS:2023:1666: 3
# ECLI:NL:RBMNE:2023:1993: 5
# ECLI:NL:RBDHA:2023:6206: 1
# ECLI:NL:RBDHA:2023:6392: 2
# ECLI:NL:RBDHA:2023:6364: 2
# ECLI:NL:RBDHA:2023:6374: 3
# ECLI:NL:RBDHA:2023:7833: 3
# ECLI:NL:GHSHE:2023:1411: 3
# ECLI:NL:GHSHE:2023:1609: 11
# ECLI:NL:RBDHA:2023:6157: 2
# ECLI:NL:RBDHA:2023:6540: 2
# ECLI:NL:GHARL:2023:3949: 5
# ECLI:NL:HR:2023:683: 1
# ECLI:NL:RBROT:2023:4852: 5
# ECLI:NL:RBAMS:2023:3421: 4
# ECLI:NL:RBNHO:2023:7439: 2
# ECLI:NL:RBNHO:2023:7434: 2
# ECLI:NL:RVS:2023:1766: 2
# ECLI:NL:RBDHA:2023:6583: 2
# ECLI:NL:RBROT:2023:3993: 7
# ECLI:NL:RBROT:2023:4021: 4
# ECLI:NL:RBDHA:2023:6985: 2
# ECLI:NL:RBDHA:2023:6968: 3
# ECLI:NL:RBZWB:2023:3314: 2
# ECLI:NL:CBB:2023:237: 5
# ECLI:NL:RBZWB:2023:3379: 3
# ECLI:NL:RVS:2023:1978: 2
# ECLI:NL:RBDHA:2023:7057: 2
# ECLI:NL:CRVB:2023:963: 4
# ECLI:NL:RBROT:2023:4206: 10
# ECLI:NL:RBDHA:2023:6734: 10
# ECLI:NL:GHAMS:2023:1283: 1
# ECLI:NL:RBDHA:2023:8307: 1
# ECLI:NL:RBDHA:2023:9658: 3
# ECLI:NL:CRVB:2023:941: 5
# ECLI:NL:RBDHA:2023:7286: 1
# ECLI:NL:GHARL:2023:4400: 5
# ECLI:NL:GHAMS:2023:1186: 2
# ECLI:NL:OGEAC:2023:114: 3
# ECLI:NL:RBDHA:2023:7449: 6
# ECLI:NL:RBOBR:2023:2574: 5
# ECLI:NL:RBDHA:2023:7552: 6
# ECLI:NL:GHSHE:2023:1737: 4
# ECLI:NL:RBDHA:2023:7628: 2
# ECLI:NL:RBROT:2023:4521: 2
# ECLI:NL:RBDHA:2023:7891: 4
# ECLI:NL:CRVB:2023:1036: 1
# ECLI:NL:RBDHA:2023:8046: 2
# ECLI:NL:RBDHA:2023:8047: 1
# ECLI:NL:GHARL:2023:4774: 6
# ECLI:NL:GHARL:2023:4745: 8
# ECLI:NL:RBDHA:2023:8346: 2
# ECLI:NL:HR:2023:841: 1
# ECLI:NL:HR:2023:843: 1
# ECLI:NL:CBB:2023:281: 2
# ECLI:NL:RBDHA:2023:8142: 7
# ECLI:NL:RBDHA:2023:8216: 2
# ECLI:NL:RBDHA:2023:8452: 3
# ECLI:NL:RBDHA:2023:8407: 4
# ECLI:NL:RBDHA:2023:8459: 1
# ECLI:NL:RBZWB:2023:4102: 1
# ECLI:NL:RBZWB:2023:4122: 2
# ECLI:NL:RVS:2023:2322: 11
# ECLI:NL:RBDHA:2023:8921: 2
# ECLI:NL:CRVB:2023:1151: 1
# ECLI:NL:RBDHA:2023:8805: 6
# ECLI:NL:RBGEL:2023:3472: 10
# ECLI:NL:RBDHA:2023:8991: 2
# ECLI:NL:RBDHA:2023:8967: 1
# ECLI:NL:RVS:2023:2433: 1
# ECLI:NL:RBDHA:2023:9083: 1
# ECLI:NL:RVS:2023:2511: 2
# ECLI:NL:RBDHA:2023:9433: 7
# ECLI:NL:RBOVE:2023:2462: 5
# ECLI:NL:RBNNE:2023:2664: 8
# ECLI:NL:RBDHA:2023:9449: 3
# ECLI:NL:RBDHA:2023:9552: 3
# ECLI:NL:RVS:2023:2555: 1
# ECLI:NL:CBB:2023:318: 5
# ECLI:NL:GHARL:2023:5596: 4
# ECLI:NL:GHARL:2023:5595: 5
# ECLI:NL:RBDHA:2023:9954: 2
# ECLI:NL:RVS:2023:2633: 1
# ECLI:NL:GHARL:2023:5857: 2
# ECLI:NL:RBZWB:2023:4900: 4
# ECLI:NL:RVS:2023:2701: 3
# ECLI:NL:CRVB:2023:1329: 3
# ECLI:NL:CRVB:2023:1355: 5
# ECLI:NL:RBDHA:2023:10365: 5
# ECLI:NL:RBNHO:2023:6765: 8
# ECLI:NL:RVS:2023:2777: 7
# ECLI:NL:RBZWB:2023:5043: 3
# ECLI:NL:RBZWB:2023:5166: 5
# ECLI:NL:RBGEL:2023:4148: 5
# ECLI:NL:RBDHA:2023:11150: 2
# ECLI:NL:RBDHA:2023:11209: 3
# ECLI:NL:RBNNE:2023:3170: 11
# ECLI:NL:GHARL:2023:6543: 10
# ECLI:NL:RBDHA:2023:11398: 2
# ECLI:NL:RBNNE:2023:3223: 10
# ECLI:NL:CRVB:2023:1469: 4
# ECLI:NL:RBDHA:2023:11792: 5
# ECLI:NL:RBNHO:2023:7750: 6
# ECLI:NL:RBZWB:2023:5842: 6
# ECLI:NL:RBDHA:2023:11843: 1
# ECLI:NL:RVS:2023:3090: 1
# ECLI:NL:RVS:2023:3036: 4
# ECLI:NL:RBDHA:2023:12357: 1
# ECLI:NL:RBDHA:2023:12058: 2
# ECLI:NL:RBDHA:2023:12261: 1
# ECLI:NL:RBDHA:2023:12499: 1
# ECLI:NL:RBDHA:2023:12257: 6
# ECLI:NL:RVS:2023:3170: 1
# ECLI:NL:RVS:2023:3189: 1
# ECLI:NL:CRVB:2023:1643: 2
# ECLI:NL:RBDHA:2023:12710: 2
# ECLI:NL:RVS:2023:3263: 1
# ECLI:NL:CBB:2023:457: 11
# ECLI:NL:HR:2023:1139: 2
# ECLI:NL:RBDHA:2023:12954: 2
# ECLI:NL:RBDHA:2023:13045: 2
# ECLI:NL:GHAMS:2023:2030: 3
# ECLI:NL:RBDHA:2023:13498: 2
# ECLI:NL:RBDHA:2023:13499: 2
# ECLI:NL:RBDHA:2023:13501: 2
# ECLI:NL:RBDHA:2023:13502: 2
# ECLI:NL:RBDHA:2023:13500: 2
# ECLI:NL:CBB:2023:464: 2
# ECLI:NL:RVS:2023:3354: 1
# ECLI:NL:RVS:2023:3373: 6
# ECLI:NL:RVS:2023:3342: 1
# ECLI:NL:RVS:2023:3363: 1
# ECLI:NL:RBDHA:2023:13706: 4
# ECLI:NL:RVS:2023:3388: 5
# ECLI:NL:CRVB:2023:1715: 3
# ECLI:NL:RBDHA:2023:13747: 2
# ECLI:NL:HR:2023:1190: 1
# ECLI:NL:RBZWB:2023:6171: 2
# ECLI:NL:RBZWB:2023:6165: 2
# ECLI:NL:RBDHA:2023:13669: 1
# ECLI:NL:RBDHA:2023:13831: 2
# ECLI:NL:RBDHA:2023:13796: 2
# ECLI:NL:RBOVE:2023:3690: 5
# ECLI:NL:RBLIM:2023:5509: 8
# ECLI:NL:RBDHA:2023:13950: 3
# ECLI:NL:RBDHA:2023:14151: 2
# ECLI:NL:GHARL:2023:7837: 3
# ECLI:NL:RBNNE:2023:3878: 6
# ECLI:NL:RBROT:2023:8720: 3
# ECLI:NL:RBDHA:2023:14233: 2
# ECLI:NL:RBDHA:2023:14588: 5
# ECLI:NL:RBZWB:2023:7002: 2
# ECLI:NL:CBB:2023:545: 4
# ECLI:NL:RBDHA:2023:14563: 2
# ECLI:NL:RBDHA:2023:14561: 2
# ECLI:NL:RBDHA:2023:14927: 2
# ECLI:NL:RBDHA:2023:14934: 4
# ECLI:NL:RBNNE:2023:3999: 7
# ECLI:NL:CBB:2023:546: 5
# ECLI:NL:RBDHA:2023:14848: 3
# ECLI:NL:RBDHA:2023:14728: 6
# ECLI:NL:RBZWB:2023:6895: 5
# ECLI:NL:RBDHA:2023:14846: 2
# ECLI:NL:RBNHO:2023:9621: 4
# ECLI:NL:HR:2023:1403: 1
# ECLI:NL:RBZWB:2023:6998: 10
# ECLI:NL:RBZWB:2023:7320: 4
# ECLI:NL:GHAMS:2023:2497: 1
# ECLI:NL:GHAMS:2023:2498: 4
# ECLI:NL:RBDHA:2023:15972: 5
# ECLI:NL:RBROT:2023:9343: 5
# ECLI:NL:GHARL:2023:8530: 6
# ECLI:NL:RBDHA:2023:15391: 1
# ECLI:NL:RVS:2023:3740: 1
# ECLI:NL:RBDHA:2023:15397: 1
# ECLI:NL:RBDHA:2023:15746: 2
# ECLI:NL:GHARL:2023:8976: 2
# ECLI:NL:RBDHA:2023:16628: 5
# ECLI:NL:RBDHA:2023:15543: 2
# ECLI:NL:RBNHO:2023:10310: 5
# ECLI:NL:GHAMS:2023:2486: 2
# ECLI:NL:RBDHA:2023:15944: 6
# ECLI:NL:CBB:2023:609: 4
# ECLI:NL:RBZWB:2023:7378: 4
# ECLI:NL:RVS:2023:3917: 1
# ECLI:NL:RBDHA:2023:16290: 2
# ECLI:NL:RBDHA:2023:16294: 2
# ECLI:NL:RVS:2023:4018: 2
# ECLI:NL:RBAMS:2023:6910: 3
# ECLI:NL:RVS:2023:4028: 4
# ECLI:NL:RBDHA:2023:16486: 3
# ECLI:NL:RBOVE:2023:4351: 3
# ECLI:NL:RBROT:2023:10404: 6
# ECLI:NL:RBNHO:2023:10945: 3
# ECLI:NL:RBROT:2023:10533: 7
# ECLI:NL:RBDHA:2023:16602: 4
# ECLI:NL:RBOVE:2023:4492: 12
# ECLI:NL:GHSHE:2023:3690: 4
# ECLI:NL:GHDHA:2023:2171: 4
# ECLI:NL:RBNHO:2023:11332: 10
# ECLI:NL:RBOVE:2023:4509: 10
# ECLI:NL:RBAMS:2023:7125: 2
# ECLI:NL:RBDHA:2023:17458: 2
# ECLI:NL:RBDHA:2023:17290: 2
# ECLI:NL:RBDHA:2023:17261: 11
# ECLI:NL:RBDHA:2023:17313: 1
# ECLI:NL:RBROT:2023:10667: 1
# ECLI:NL:RBDHA:2023:17302: 3
# ECLI:NL:HR:2023:1590: 1
# ECLI:NL:RBAMS:2023:7327: 6
# ECLI:NL:RBDHA:2023:18032: 2
# ECLI:NL:CRVB:2023:2164: 2
# ECLI:NL:RBROT:2023:10899: 3
# ECLI:NL:RBZWB:2023:8080: 5
# ECLI:NL:RBDHA:2023:17826: 4
# ECLI:NL:RBOVE:2023:4743: 4
# ECLI:NL:RBDHA:2023:18040: 4
# ECLI:NL:RBDHA:2023:18152: 2
# ECLI:NL:RBDHA:2023:18446: 1
# ECLI:NL:RBDHA:2023:18338: 4
# ECLI:NL:RVS:2023:4409: 10
# ECLI:NL:CRVB:2023:2225: 4
# ECLI:NL:RVS:2023:4477: 1
# ECLI:NL:RBDHA:2023:18658: 2
# ECLI:NL:RBNHO:2023:12427: 4
# ECLI:NL:RBDHA:2023:19048: 2
# ECLI:NL:RBDHA:2023:19256: 3
# ECLI:NL:RBDHA:2023:19425: 3
# ECLI:NL:RVS:2023:4550: 1
# ECLI:NL:RBROT:2023:11796: 2
# ECLI:NL:RBDHA:2023:19288: 1
# ECLI:NL:RBNNE:2023:5114: 10
# ECLI:NL:GHARL:2023:10547: 3
# ECLI:NL:RBDHA:2023:19847: 1
# ECLI:NL:RBMNE:2023:6728: 6
# ECLI:NL:RBDHA:2023:19896: 2
# ECLI:NL:RBDHA:2023:19272: 5
# ECLI:NL:RBOVE:2023:5213: 11
# ECLI:NL:RBDHA:2023:20266: 3
# ECLI:NL:RBDHA:2023:20134: 2
# ECLI:NL:RBAMS:2023:8426: 8
# ECLI:NL:RBGEL:2023:7123: 2
# ECLI:NL:RBROT:2023:12640: 2
# ECLI:NL:RVS:2023:4838: 5
# ECLI:NL:RBZWB:2023:9192: 10
# ECLI:NL:RBZWB:2023:9196: 10
# ECLI:NL:GHAMS:2023:3528: 3
# ECLI:NL:RBROT:2023:12734: 3
# ECLI:NL:RBZWB:2023:9624: 3
# Creation of new index succesfull.
# rechtspraak_metadata_2024.xlsx
# ECLI:NL:RBDHA:2024:75: 4
# ECLI:NL:RVS:2024:26: 1
# ECLI:NL:GHAMS:2024:26: 5
# ECLI:NL:CBB:2024:8: 3
# ECLI:NL:CBB:2024:9: 2
# ECLI:NL:RVS:2024:112: 8
# ECLI:NL:GHAMS:2024:104: 5
# ECLI:NL:RBLIM:2024:176: 4
# ECLI:NL:RBDHA:2024:702: 1
# ECLI:NL:RBDHA:2024:426: 5
# ECLI:NL:RVS:2024:138: 3
# ECLI:NL:RBOBR:2024:133: 11
# ECLI:NL:RBROT:2024:419: 3
# ECLI:NL:RBNHO:2024:377: 5
# ECLI:NL:RBDHA:2024:565: 2
# ECLI:NL:RVS:2024:192: 1
# ECLI:NL:RBDHA:2024:797: 3
# ECLI:NL:RBOVE:2024:461: 4
# ECLI:NL:RBGEL:2024:398: 2
# ECLI:NL:RBDHA:2024:954: 4
# ECLI:NL:RVS:2024:319: 1
# ECLI:NL:RBNHO:2024:718: 10
# ECLI:NL:HR:2024:127: 1
# ECLI:NL:RVS:2024:429: 1
# ECLI:NL:RBROT:2024:309: 6
# ECLI:NL:RBDHA:2024:1795: 3
# ECLI:NL:RBDHA:2024:1242: 1
# ECLI:NL:RBOVE:2024:672: 3
# ECLI:NL:RBZWB:2024:767: 3
# ECLI:NL:RBDHA:2024:1581: 1
# ECLI:NL:RBDHA:2024:1578: 1
# ECLI:NL:RBDHA:2024:1514: 1
# ECLI:NL:RBDHA:2024:1676: 2
# ECLI:NL:RBDHA:2024:1679: 2
# ECLI:NL:RBDHA:2024:1884: 3
# ECLI:NL:RVS:2024:622: 7
# ECLI:NL:RVS:2024:614: 6
# ECLI:NL:CRVB:2024:291: 1
# ECLI:NL:RBDHA:2024:1891: 1
# ECLI:NL:RVS:2024:597: 1
# ECLI:NL:CRVB:2024:316: 2
# ECLI:NL:RBDHA:2024:1993: 2
# ECLI:NL:RBDHA:2024:2077: 1
# ECLI:NL:RVS:2024:670: 1
# ECLI:NL:RBDHA:2024:2169: 6
# ECLI:NL:HR:2024:272: 1
# ECLI:NL:HR:2024:271: 1
# ECLI:NL:RBDHA:2024:2312: 4
# ECLI:NL:RBDHA:2024:2439: 4
# ECLI:NL:RBDHA:2024:2669: 2
# ECLI:NL:HR:2024:309: 1
# ECLI:NL:RBOBR:2024:826: 10
# ECLI:NL:HR:2024:335: 1
# ECLI:NL:RBDHA:2024:3120: 2
# ECLI:NL:RBDHA:2024:3280: 1
# ECLI:NL:RBOVE:2024:1345: 3
# ECLI:NL:RBOVE:2024:1347: 2
# ECLI:NL:RBOVE:2024:1344: 4
# ECLI:NL:RBZWB:2024:1814: 2
# ECLI:NL:RVS:2024:1061: 4
# ECLI:NL:RVS:2024:1024: 2
# ECLI:NL:RBZWB:2024:1838: 3
# ECLI:NL:RBOBR:2024:1145: 3
# ECLI:NL:RVS:2024:1208: 1
# ECLI:NL:RVS:2024:1180: 1
# ECLI:NL:RBDHA:2024:4386: 1
# ECLI:NL:RBROT:2024:2735: 4
# ECLI:NL:RBDHA:2024:4059: 2
# ECLI:NL:RBGEL:2024:1651: 5
# ECLI:NL:RBDHA:2024:4467: 1
# ECLI:NL:RBLIM:2024:1540: 3
# ECLI:NL:RBZWB:2024:2088: 2
# ECLI:NL:RBZWB:2024:2354: 3
# ECLI:NL:RBZWB:2024:2372: 5
# ECLI:NL:CBB:2024:241: 1
# ECLI:NL:RBDHA:2024:4837: 2
# ECLI:NL:RBZWB:2024:2304: 10
# ECLI:NL:RVS:2024:1475: 1
# ECLI:NL:RVS:2024:1506: 5
# ECLI:NL:RVS:2024:1511: 8
# ECLI:NL:RBDHA:2024:5432: 2
# ECLI:NL:HR:2024:448: 1
# ECLI:NL:RVS:2024:1537: 1
# ECLI:NL:RBMNE:2024:2321: 4
# ECLI:NL:RBDHA:2024:5576: 2
# ECLI:NL:RBDHA:2024:5702: 2
# ECLI:NL:RBZWB:2024:2681: 4
# ECLI:NL:RBDHA:2024:5761: 2
# ECLI:NL:RBMNE:2024:2486: 9
# ECLI:NL:GHARL:2024:2811: 11
# ECLI:NL:RBDHA:2024:6311: 2
# ECLI:NL:RBDHA:2024:6367: 4
# ECLI:NL:RBZWB:2024:2759: 4
# ECLI:NL:RBZWB:2024:2718: 2
# ECLI:NL:RBZWB:2024:2751: 3
# ECLI:NL:RBDHA:2024:6652: 9
# ECLI:NL:CBB:2024:306: 3
# ECLI:NL:RBAMS:2024:2459: 4
# Creation of new index succesfull.

# %%
# # first delete current index
# # if delete_index():
# #     for _ in range(12):
# #         time.sleep(5)
# #         if check_index_deleted():
# print("Index has been deleted. Continue...")

# # init new index
# acs = init_acs()

# # init chunk parameters
# documents = []
# params = {
#     "splitter": "TokenTextSplitter",
#     "encoding_name": "cl100k_base",
#     "chunk_size": 1536,
#     "chunk_overlap": 32,
# }
# token_splitter = TokenTextSplitter(
#     encoding_name=params["encoding_name"],
#     chunk_size=params["chunk_size"],
#     chunk_overlap=params["chunk_overlap"],
# )

# ##PDF##
# document_path = "documents/"
# pdfs = {}
# for pdf_file in os.scandir(document_path):
#     if pdf_file.name.endswith(".pdf"):
#         filename = pdf_file.name
#         content_dict = pdf_reading(document_path, filename)
#         for page, content in content_dict.items():
#             chunks = token_splitter.split_text(content)
#             print(f"{filename}|{page}|{len(chunks)}")
#             for idx, chunk in enumerate(chunks):
#                 doc = Document(
#                     page_content=chunk,
#                     metadata={
#                         "title": filename,
#                         "page": str(page),
#                     },
#                 )
#                 documents.append(doc.copy())

# # ADD ALL CHUNKS TO ACS
# acs.add_documents(documents)
# print("Creation of new index succesfull.")
# Out:
# Index has been deleted. Continue...
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|0|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|2|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|3|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|4|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|5|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|6|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|7|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|8|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|9|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|10|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|11|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|12|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|13|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|14|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|15|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|16|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|17|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|18|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|19|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|20|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|21|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|22|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|23|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|24|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|25|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|26|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|27|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|28|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|29|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|30|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|31|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|32|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|33|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|34|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|35|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|36|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|37|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|38|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|39|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|40|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|41|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|42|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|43|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|44|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|45|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|46|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|47|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|48|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|49|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|50|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|51|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|52|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|53|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|54|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|55|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|56|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|57|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|58|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|59|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|60|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|61|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|62|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|63|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|64|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|65|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|66|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|67|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|68|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|69|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|70|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|71|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|72|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|73|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|74|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|75|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|76|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|77|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|78|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|79|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|80|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|81|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|82|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|83|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|84|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|85|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|86|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|87|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|88|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|89|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|90|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|91|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|92|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|93|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|94|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|95|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|96|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|97|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|98|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|99|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|100|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|101|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|102|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|103|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|104|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|105|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|106|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|107|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|108|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|109|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|110|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|111|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|112|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|113|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|114|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|115|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|116|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|117|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|118|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|119|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|120|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|121|1
# 01 De Cock en een strop voor Bobby - A.C. Baantjer.pdf|122|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|0|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|2|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|3|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|4|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|5|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|6|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|7|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|8|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|9|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|10|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|11|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|12|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|13|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|14|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|15|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|16|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|17|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|18|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|19|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|20|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|21|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|22|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|23|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|24|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|25|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|26|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|27|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|28|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|29|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|30|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|31|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|32|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|33|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|34|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|35|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|36|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|37|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|38|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|39|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|40|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|41|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|42|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|43|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|44|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|45|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|46|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|47|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|48|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|49|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|50|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|51|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|52|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|53|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|54|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|55|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|56|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|57|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|58|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|59|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|60|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|61|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|62|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|63|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|64|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|65|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|66|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|67|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|68|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|69|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|70|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|71|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|72|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|73|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|74|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|75|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|76|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|77|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|78|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|79|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|80|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|81|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|82|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|83|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|84|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|85|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|86|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|87|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|88|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|89|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|90|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|91|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|92|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|93|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|94|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|95|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|96|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|97|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|98|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|99|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|100|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|101|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|102|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|103|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|104|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|105|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|106|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|107|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|108|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|109|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|110|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|111|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|112|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|113|1
# 04 De Cock en de moord op Anna Bentveld - A.C. Baantjer.pdf|114|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|0|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|1|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|2|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|3|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|4|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|5|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|6|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|7|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|8|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|9|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|10|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|11|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|12|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|13|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|14|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|15|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|16|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|17|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|18|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|19|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|20|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|21|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|22|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|23|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|24|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|25|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|26|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|27|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|28|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|29|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|30|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|31|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|32|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|33|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|34|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|35|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|36|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|37|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|38|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|39|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|40|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|41|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|42|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|43|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|44|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|45|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|46|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|47|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|48|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|49|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|50|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|51|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|52|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|53|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|54|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|55|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|56|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|57|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|58|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|59|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|60|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|61|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|62|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|63|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|64|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|65|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|66|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|67|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|68|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|69|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|70|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|71|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|72|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|73|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|74|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|75|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|76|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|77|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|78|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|79|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|80|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|81|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|82|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|83|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|84|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|85|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|86|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|87|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|88|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|89|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|90|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|91|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|92|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|93|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|94|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|95|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|96|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|97|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|98|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|99|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|100|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|101|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|102|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|103|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|104|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|105|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|106|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|107|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|108|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|109|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|110|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|111|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|112|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|113|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|114|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|115|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|116|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|117|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|118|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|119|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|120|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|121|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|122|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|123|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|124|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|125|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|126|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|127|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|128|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|129|1
# 05 De Cock en het sombere naakt - A.C. Baantjer.pdf|130|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|0|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|2|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|3|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|4|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|5|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|6|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|7|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|8|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|9|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|10|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|11|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|12|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|13|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|14|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|15|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|16|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|17|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|18|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|19|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|20|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|21|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|22|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|23|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|24|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|25|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|26|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|27|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|28|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|29|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|30|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|31|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|32|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|33|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|34|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|35|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|36|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|37|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|38|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|39|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|40|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|41|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|42|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|43|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|44|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|45|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|46|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|47|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|48|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|49|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|50|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|51|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|52|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|53|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|54|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|55|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|56|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|57|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|58|1
# 03 De Cock en het lijk in de kerstnacht - A.C. Baantjer.pdf|59|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|0|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|3|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|4|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|5|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|6|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|7|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|8|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|9|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|10|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|11|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|12|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|13|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|14|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|15|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|16|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|17|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|18|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|19|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|20|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|21|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|22|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|23|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|24|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|25|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|26|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|27|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|28|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|29|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|30|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|31|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|32|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|33|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|34|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|35|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|36|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|37|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|38|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|39|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|40|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|41|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|42|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|43|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|44|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|45|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|46|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|47|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|48|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|49|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|50|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|51|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|52|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|53|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|54|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|55|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|56|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|57|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|58|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|59|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|60|1
# 02 De Cock en de wurger op zondag - A.C. Baantjer.pdf|61|1
# Creation of new index succesfull.
